# %%
import json;import datetime;from datetime import timedelta;import os, zipfile;
import pandas as pd;from scipy.optimize import curve_fit;from scipy.stats import chisquare
import numpy as np;import matplotlib.pyplot as plt
from LifeBuddyWebApp import create_app, db
from LifeBuddyWebApp.models import User, Post, Health_description, Health_measure
proxyApp=create_app()
ctx=proxyApp.app_context()
ctx.push()
from sqlalchemy import func

from bokeh.plotting import figure, output_file, show
import pandas as pd
from bokeh.resources import CDN
from bokeh.models import ColumnDataSource, Grid, LinearAxis, Plot, Text, Span
from bokeh.io import curdoc
from bokeh.themes import built_in_themes, Theme

from bokeh.layouts import row
import time
import pytz
import zoneinfo
from pytz import timezone
# Out:
# C:\tools\miniconda3\envs\lifebuddy\lib\site-packages\flask_sqlalchemy\__init__.py:872: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   warnings.warn(FSADeprecationWarning(

# %%
#filter on user data only
base_query_health_description=db.session.query(Health_description).filter(Health_description.user_id==1)
# if current_user.id==2:
df_health_description=pd.read_sql(str(base_query_health_description)[:-1]+str(1),db.session.bind)
# else:
#     df_health_description=pd.read_sql(str(base_query_health_description)[:-1]+str(current_user.id),db.session.bind)

# %%
#This stays exactly
colNames=[i[len('health_description_'):] for i in list(df_health_description.columns)]
col_names_dict={i:j for i,j in zip(list(df_health_description.columns),colNames)}
df_health_description.rename(columns=col_names_dict, inplace=True)

# %%
def plot_text_format(x):
    return ('%.1f' % x).rstrip('0').rstrip('.')

# %%
#This stays exactly
df1=df_health_description.loc[df_health_description.metric1_carido<100]
df1=df1.sort_values(by=['datetime_of_activity'])
obs_x1=[ datetime.datetime.strptime(date_string,'%Y-%m-%d %H:%M:%S.%f') for date_string in df1.datetime_of_activity]
obs_y1=df1.metric1_carido
obs_y1_formatted=[ plot_text_format(i) for i in obs_y1]

date_end=datetime.datetime.strptime(df1.datetime_of_activity.to_list()[-1],'%Y-%m-%d %H:%M:%S.%f')
date_end=date_end+ timedelta(days=5)
date_start=date_end- timedelta(days=7)

# %%
#get x and y's for activity
df2=df_health_description.loc[(df_health_description.var_type=='Activity') ]
#1 time (obs_x)
obs_x2=[ datetime.datetime.strptime(date_string,'%Y-%m-%d %H:%M:%S.%f') for date_string in df2.datetime_of_activity]
#3 activity (obs_y2)
obs_y2=df2.var_activity.to_list()

# %%
fig1=figure(toolbar_location=None,tools='xwheel_zoom,xpan',active_scroll='xwheel_zoom',
            x_range=(date_start,date_end),y_range=(-10,90),width=800, height=300)

#add cardio_metric1
circle=fig1.circle(obs_x1,obs_y1, legend_label="Cardio Performance", fill_color='#c77711', line_color=None,
                  size=20)
source1 = ColumnDataSource(dict(x=obs_x1, y=obs_y1, text=obs_y1_formatted))
glyph1 = Text(text="text",text_font_size={'value': '10px'},x_offset=-10, y_offset=5)
fig1.add_glyph(source1, glyph1)

for a,b in zip(obs_x2,obs_y2):
    #add activity data
    source2 = ColumnDataSource(dict(x=[a], y=[80], text=[b]))
    glyph2 = Text(text="text", text_color="#414444", text_font_size={'value': '10px'},
                 x_offset=-10,angle=-1.58)

    #add line for activity data
    line_start_time=time.mktime(a.timetuple())*1000
    important_time = Span(location=line_start_time, dimension='height', line_color="#414444", line_dash='dashed', line_width=1)
    fig1.add_glyph(source2, glyph2)
    fig1.add_layout(important_time)

fig1.add_glyph(source2, glyph2)
fig1.ygrid.grid_line_color = None
fig1.yaxis.major_label_text_color = None
fig1.yaxis.major_tick_line_color = None
fig1.yaxis.minor_tick_line_color = None

fig1.legend.background_fill_color = "#578582"
fig1.legend.background_fill_alpha = 0.2
fig1.legend.border_line_color = None

curdoc().theme = Theme(filename=r"D:\OneDrive\Documents\professional\20210710lifeBuddy\chart_theme_2.yml")
show(fig1)
# Out:
# ERROR:bokeh.core.validation.check:E-1020 (BAD_EXTRA_RANGE_NAME): An extra range name is configued with a name that does not correspond to any range: x_range_name='2021-08-18 14:04:09.641000' [Legend(id='25695', ...)]

# %% [markdown]
# Timeline Records table scratch work

# %%
#filter on user data only
# base_query_health_description=db.session.query(Health_description).filter(Health_description.user_id==1)
# if current_user.id==2:
# df_health_description=pd.read_sql(str(base_query_health_description)[:-1]+str(1),db.session.bind)
df_health_description.head()
# Out:
#    id        datetime_of_activity       var_activity    var_type  \
# 0   1  2021-06-09 12:08:34.635000               YOGA  heart rate
# 1   2  2021-07-19 09:58:41.657000            RUNNING  heart rate
# 2   3  2021-04-01 10:53:23.421000  TREADMILL_RUNNING  heart rate
# 3   4  2021-03-21 13:01:19.783000            JOGGING  heart rate
# 4   5  2021-03-29 12:26:53.276000            WALKING  heart rate
#
#   var_periodicity  var_timezone_utc_delta_in_mins              time_stamp_utc  \
# 0         seconds                          -240.0  2021-08-22 15:13:51.668660
# 1         seconds                           120.0  2021-08-22 15:13:51.684289
# 2         seconds                          -240.0  2021-08-22 15:13:51.715539
# 3         seconds                          -240.0  2021-08-22 15:13:51.746789
# 4         seconds                          -240.0  2021-08-22 15:13:51.784548
#
#    user_id                                    source_filename  \
# 0        1  training-session-2021-06-09-6138678344-024ee81...
# 1        1  training-session-2021-07-19-6283868904-0286c7f...
# 2        1  training-session-2021-04-01-5865912594-028fd1f...
# 3        1  training-session-2021-03-21-5816145734-02a0a7b...
# 4        1  training-session-2021-03-29-5853175779-034ad3a...
#
#       metric1_carido  metric2_session_duration  metric3 metric4 metric5  note
# 0  21.73378181755639                     359.0      NaN    None    None  None
# 1  8.914897938722028                     888.0      NaN    None    None  None
# 2 15.078394092203483                     364.0      NaN    None    None  None
# 3 11.016714047169142                   1,080.0      NaN    None    None  None
# 4                NaN                      75.0      NaN    None    None  None

# %%
df_sub=df_health_description[['id', 'datetime_of_activity', 'var_activity','metric1_carido',
                             'metric2_session_duration','metric3']].copy()
df_sub.datetime_of_activity=df_sub['datetime_of_activity'].astype('datetime64[ns]')
df_sub.datetime_of_activity=pd.to_datetime(df_sub["datetime_of_activity"].dt.strftime('%m/%d/%Y %H:%M'))
df_sub.metric1_carido=df_sub.metric1_carido.round(2)
df_sub.metric2_session_duration=df_sub.metric2_session_duration.astype('Int64')
df_sub.metric2_session_duration=df_sub.metric2_session_duration.apply('{:,}'.format)
df_sub.metric2_session_duration=df_sub.metric2_session_duration.str.replace('<NA>','')
df_sub.metric3=df_sub.metric3.astype('float')
# df_sub.metric3=df_sub.metric3.str.replace('<NA>','')

df_sub=df_sub.where(pd.notnull(df_sub), '')
df_sub=df_sub.sort_values(by=['datetime_of_activity'],ascending=False)

# %%
df_sub.head()
# Out:
#       id datetime_of_activity          var_activity metric1_carido  \
# 251  252  2021-08-24 08:18:00               woke up
# 252  253  2021-08-24 02:20:00  Working on computer
# 250  251  2021-08-23 05:30:00                coffee
# 249  250  2021-08-22 21:08:00         activity-walk
# 156  157  2021-08-20 14:04:00            BASKETBALL          27.75
#
#     metric2_session_duration metric3
# 251                            169.0
# 252
# 250
# 249                            160.0
# 156                    3,253

# %%
# df_sub.metric2_session_duration=df_sub.metric2_session_duration.str.replace('<NA>','')
df_sub.dtypes
# Out:
# id                                   int64
# datetime_of_activity        datetime64[ns]
# var_activity                        object
# metric1_carido                      object
# metric2_session_duration            object
# metric3                             object
# dtype: object

# %%
# Out:
#       id datetime_of_activity          var_activity  metric1_carido
# 221  222  2021-03-10 14:28:00          OTHER_INDOOR      118.736291
# 245  246  2021-03-10 14:36:00               JOGGING       22.997104
# 75    76  2021-03-10 15:11:00          OTHER_INDOOR       32.996597
# 191  192  2021-03-12 14:51:00          OTHER_INDOOR       77.831994
# 205  206  2021-03-12 14:54:00               JOGGING       15.033158
# ..   ...                  ...                   ...             ...
# 156  157  2021-08-20 14:04:00            BASKETBALL       27.747436
# 249  250  2021-08-22 21:08:00         activity-walk             NaN
# 250  251  2021-08-23 05:30:00                coffee             NaN
# 252  253  2021-08-24 02:20:00  Working on computer              NaN
# 251  252  2021-08-24 08:18:00               woke up             NaN
#
# [253 rows x 4 columns]

# %%
table_lists=df_sub.values.tolist()

# %%
for i in table_lists:
        i[3]='{0:.3g}'.format(i[3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-c074541f6e6f> in <module>
#       1 for i in table_lists:
# ----> 2         i[3]='{0:.3g}'.format(i[3])
#
# ValueError: Unknown format code 'g' for object of type 'str'

# %%
table_lists
# Out:
# [[1, Timestamp('2021-06-09 12:08:00'), 'YOGA', 21.73378181755639],
#  [2, Timestamp('2021-07-19 09:58:00'), 'RUNNING', 8.914897938722028],
#  [3,
#   Timestamp('2021-04-01 10:53:00'),
#   'TREADMILL_RUNNING',
#   15.078394092203483],
#  [4, Timestamp('2021-03-21 13:01:00'), 'JOGGING', 11.016714047169142],
#  [5, Timestamp('2021-03-29 12:26:00'), 'WALKING', ''],
#  [6,
#   Timestamp('2021-05-21 12:00:00'),
#   'STRENGTH_TRAINING',
#   22.242826431801284],
#  [7, Timestamp('2021-03-26 10:46:00'), 'WALKING', 28.586845993303474],
#  [8, Timestamp('2021-06-09 12:00:00'), 'WALKING', 0.10332960374691504],
#  [9, Timestamp('2021-07-24 10:07:00'), 'RUNNING', 10.392354587865132],
#  [10, Timestamp('2021-04-21 09:59:00'), 'WALKING', 0.15857185759225118],
#  [11, Timestamp('2021-06-07 11:58:00'), 'RUNNING', 5.9513109468612315],
#  [12, Timestamp('2021-04-11 12:15:00'), 'JOGGING', 11.317183575548345],
#  [13, Timestamp('2021-03-26 11:03:00'), 'YOGA', 35.388215996691144],
#  [14,
#   Timestamp('2021-05-15 11:09:00'),
#   'STRENGTH_TRAINING',
#   16.984399495999284],
#  [15, Timestamp('2021-06-07 12:08:00'), 'WALKING', 0.03609512446937683],
#  [16, Timestamp('2021-05-17 11:23:00'), 'RUNNING', 4.642758396693931],
#  [17, Timestamp('2021-08-09 14:18:00'), 'YOGA', 53.31756926758648],
#  [18, Timestamp('2021-05-18 11:32:00'), 'YOGA', 11.919939371827335],
#  [19, Timestamp('2021-04-25 12:47:00'), 'YOGA', 20.4400032163702],
#  [20, Timestamp('2021-07-19 10:13:00'), 'WALKING', 3.3193875315923482],
#  [21, Timestamp('2021-05-25 11:55:00'), 'RUNNING', 37.74056278607653],
#  [22,
#   Timestamp('2021-07-31 12:40:00'),
#   'STRENGTH_TRAINING',
#   31.025314625576822],
#  [23, Timestamp('2021-05-18 11:26:00'), 'WALKING', 0.14697913050378122],
#  [24, Timestamp('2021-03-30 13:44:00'), 'JOGGING', 15.701451842008531],
#  [25,
#   Timestamp('2021-03-30 14:26:00'),
#   'STRENGTH_TRAINING',
#   32.14720024769241],
#  [26, Timestamp('2021-03-25 10:42:00'), 'JOGGING', ''],
#  [27, Timestamp('2021-04-03 11:03:00'), 'WALKING', ''],
#  [28, Timestamp('2021-03-17 11:41:00'), 'OTHER_INDOOR', 18.538696157670707],
#  [29, Timestamp('2021-07-19 09:32:00'), 'RUNNING', 23.82833256348669],
#  [30, Timestamp('2021-05-05 11:16:00'), 'RUNNING', 23.00416567277035],
#  [31, Timestamp('2021-05-21 11:17:00'), 'RUNNING', 18.054292739235425],
#  [32, Timestamp('2021-04-26 13:42:00'), 'WALKING', 3.606271626805],
#  [33, Timestamp('2021-04-08 14:39:00'), 'WALKING', 24.879165763825323],
#  [34, Timestamp('2021-05-08 11:08:00'), 'WALKING', 4.549573246225717],
#  [35, Timestamp('2021-03-27 09:53:00'), 'WALKING', 27.23886744025406],
#  [36, Timestamp('2021-07-20 09:39:00'), 'WALKING', 2.0396967187827073],
#  [37, Timestamp('2021-07-31 12:15:00'), 'WALKING', 2.1350442704996895],
#  [38, Timestamp('2021-06-18 09:44:00'), 'WALKING', 0.15320714903389182],
#  [39, Timestamp('2021-03-29 12:40:00'), 'JOGGING', 9.904541534324553],
#  [40, Timestamp('2021-07-25 11:23:00'), 'YOGA', 47.19361903244212],
#  [41,
#   Timestamp('2021-08-13 14:52:00'),
#   'STRENGTH_TRAINING',
#   45.489705258779686],
#  [42, Timestamp('2021-04-26 14:01:00'), 'YOGA', 22.161976430135848],
#  [43, Timestamp('2021-03-31 12:06:00'), 'JOGGING', 12.408583890187717],
#  [44, Timestamp('2021-04-20 11:15:00'), 'JOGGING', 9.350380146425131],
#  [45, Timestamp('2021-05-21 11:36:00'), 'WALKING', 19.42431077771189],
#  [46, Timestamp('2021-05-10 09:25:00'), 'WALKING', 22.6715263858128],
#  [47, Timestamp('2021-03-30 13:56:00'), 'JOGGING', 10.763901107625795],
#  [48, Timestamp('2021-03-25 18:49:00'), 'WALKING', 40.70043226339461],
#  [49, Timestamp('2021-03-27 09:58:00'), 'YOGA', 45.87415896693836],
#  [50, Timestamp('2021-03-31 11:53:00'), 'JOGGING', 19.311175346392343],
#  [51,
#   Timestamp('2021-06-03 12:53:00'),
#   'STRENGTH_TRAINING',
#   15.690439808568168],
#  [52, Timestamp('2021-06-01 11:22:00'), 'BASKETBALL', 50.01228816390929],
#  [53, Timestamp('2021-07-31 12:24:00'), 'YOGA', 35.89040999901413],
#  [54, Timestamp('2021-08-03 14:44:00'), 'YOGA', 33.901866685149116],
#  [55, Timestamp('2021-05-27 11:12:00'), 'RUNNING', 18.5802673344722],
#  [56, Timestamp('2021-03-28 16:07:00'), 'BASKETBALL', 11.616311037372164],
#  [57, Timestamp('2021-08-14 13:21:00'), 'YOGA', 31.162783361618104],
#  [58, Timestamp('2021-04-20 11:04:00'), 'JOGGING', 7.664119164712847],
#  [59, Timestamp('2021-05-09 12:27:00'), 'RUNNING', 17.394949897602576],
#  [60, Timestamp('2021-04-03 11:06:00'), 'JOGGING', 16.97567399182405],
#  [61, Timestamp('2021-03-16 11:54:00'), 'JOGGING', 15.410181741219558],
#  [62, Timestamp('2021-04-11 12:02:00'), 'JOGGING', 19.591847786819365],
#  [63, Timestamp('2021-06-07 11:54:00'), 'WALKING', 0.4047016678073517],
#  [64,
#   Timestamp('2021-05-16 12:04:00'),
#   'STRENGTH_TRAINING',
#   18.596145633120102],
#  [65, Timestamp('2021-03-29 12:54:00'), 'YOGA', 34.50324462505866],
#  [66, Timestamp('2021-08-14 13:06:00'), 'WALKING', 2.311802505806125],
#  [67, Timestamp('2021-06-18 09:26:00'), 'RUNNING', 25.441710823880275],
#  [68, Timestamp('2021-03-29 12:24:00'), 'JOGGING', ''],
#  [69, Timestamp('2021-07-24 10:33:00'), 'YOGA', 39.749999999657],
#  [70, Timestamp('2021-03-17 11:12:00'), 'JOGGING', 17.92230129387992],
#  [71, Timestamp('2021-03-29 12:19:00'), 'JOGGING', 22.00540847113052],
#  [72, Timestamp('2021-05-15 10:27:00'), 'RUNNING', 23.890002044251162],
#  [73, Timestamp('2021-08-07 13:27:00'), 'RUNNING', 27.740178744481035],
#  [74, Timestamp('2021-07-30 13:03:00'), 'WALKING', 1.2788461398502666],
#  [75, Timestamp('2021-04-08 14:45:00'), 'YOGA', 32.69450779284092],
#  [76, Timestamp('2021-03-10 15:11:00'), 'OTHER_INDOOR', 32.996597443428115],
#  [77, Timestamp('2021-03-26 10:49:00'), 'JOGGING', 10.878673984815254],
#  [78, Timestamp('2021-05-21 11:45:00'), 'YOGA', 31.987887028351416],
#  [79, Timestamp('2021-05-27 11:39:00'), 'YOGA', 38.887041199100985],
#  [80, Timestamp('2021-05-10 09:17:00'), 'WALKING', 9.687851339588391],
#  [81, Timestamp('2021-03-26 10:43:00'), 'JOGGING', 10.285911753320654],
#  [82, Timestamp('2021-07-21 10:40:00'), 'BASKETBALL', 46.26069533922947],
#  [83, Timestamp('2021-05-23 13:37:00'), 'RUNNING', 27.383311282684744],
#  [84, Timestamp('2021-03-30 14:01:00'), 'WALKING', 20.520735782809616],
#  [85, Timestamp('2021-05-18 11:22:00'), 'RUNNING', 3.5576981857780856],
#  [86, Timestamp('2021-04-11 12:08:00'), 'JOGGING', ''],
#  [87, Timestamp('2021-05-08 11:14:00'), 'WALKING', 0.8427605680237386],
#  [88, Timestamp('2021-04-09 11:52:00'), 'BASKETBALL', 33.57559262799129],
#  [89, Timestamp('2021-03-23 14:25:00'), 'OTHER_INDOOR', 917.8255087231332],
#  [90, Timestamp('2021-03-15 13:01:00'), 'JOGGING', 21.49594307835425],
#  [91, Timestamp('2021-07-23 09:44:00'), 'RUNNING', 26.427172577012],
#  [92, Timestamp('2021-03-25 09:46:00'), 'BODY_AND_MIND', 153.4219277114326],
#  [93,
#   Timestamp('2021-03-29 13:07:00'),
#   'STRENGTH_TRAINING',
#   23.577925078454754],
#  [94, Timestamp('2021-06-03 12:30:00'), 'WALKING', 9.53490439158991],
#  [95, Timestamp('2021-06-20 09:11:00'), 'WALKING', 2.010371655105098],
#  [96, Timestamp('2021-03-31 12:20:00'), 'YOGA', 29.299986738888922],
#  [97, Timestamp('2021-03-30 14:12:00'), 'YOGA', 34.06216560508992],
#  [98, Timestamp('2021-06-25 15:01:00'), 'YOGA', 19.105799208403948],
#  [99, Timestamp('2021-06-07 12:26:00'), 'YOGA', 15.783926705324873],
#  [100, Timestamp('2021-07-25 10:31:00'), 'RUNNING', 27.01935224161523],
#  [101, Timestamp('2021-04-01 10:50:00'), 'WALKING', ''],
#  [102, Timestamp('2021-05-05 11:27:00'), 'WALKING', ''],
#  [103, Timestamp('2021-05-05 11:29:00'), 'RUNNING', 4.1587231060637455],
#  [104, Timestamp('2021-08-14 12:44:00'), 'RUNNING', 23.797769857994],
#  [105, Timestamp('2021-03-12 15:25:00'), 'OTHER_INDOOR', 18.783402659989118],
#  [106, Timestamp('2021-05-05 11:45:00'), 'YOGA', 11.713058607626593],
#  [107, Timestamp('2021-04-11 12:14:00'), 'WALKING', ''],
#  [108, Timestamp('2021-05-16 11:23:00'), 'RUNNING', 18.548770340155226],
#  [109, Timestamp('2021-07-30 12:29:00'), 'RUNNING', 30.658246475370277],
#  [110, Timestamp('2021-05-16 11:50:00'), 'YOGA', 27.913904142389868],
#  [111,
#   Timestamp('2021-06-25 15:13:00'),
#   'STRENGTH_TRAINING',
#   15.758811910242937],
#  [112, Timestamp('2021-07-26 09:53:00'), 'RUNNING', 21.139580003612014],
#  [113, Timestamp('2021-08-07 14:02:00'), 'WALKING', 5.43994187462183],
#  [114, Timestamp('2021-08-12 13:58:00'), 'RUNNING', 22.469526438735777],
#  [115, Timestamp('2021-04-01 10:59:00'), 'WALKING', 21.435806912039595],
#  [116, Timestamp('2021-04-01 10:29:00'), 'JOGGING', 56.56968054587985],
#  [117, Timestamp('2021-06-16 10:33:00'), 'RUNNING', 18.363482168103936],
#  [118, Timestamp('2021-04-01 11:04:00'), 'YOGA', 36.01326830059947],
#  [119,
#   Timestamp('2021-08-09 14:36:00'),
#   'STRENGTH_TRAINING',
#   19.545059202874885],
#  [120, Timestamp('2021-08-13 14:09:00'), 'WALKING', 21.987177051173173],
#  [121, Timestamp('2021-03-25 18:37:00'), 'JOGGING', 18.493203864114072],
#  [122, Timestamp('2021-03-27 09:41:00'), 'JOGGING', 23.49188681487566],
#  [123, Timestamp('2021-07-26 10:24:00'), 'WALKING', 6.181445460598825],
#  [124, Timestamp('2021-03-31 12:01:00'), 'WALKING', 22.68803992113452],
#  [125, Timestamp('2021-04-01 10:44:00'), 'JOGGING', 17.267782406232403],
#  [126, Timestamp('2021-04-26 13:26:00'), 'RUNNING', 15.783370444829426],
#  [127, Timestamp('2021-07-27 09:56:00'), 'RUNNING', 29.48894757975682],
#  [128, Timestamp('2021-05-17 11:26:00'), 'WALKING', 0.3617575268113732],
#  [129, Timestamp('2021-05-10 09:05:00'), 'RUNNING', 18.044165143293224],
#  [130, Timestamp('2021-03-31 12:14:00'), 'WALKING', 17.97698778826495],
#  [131, Timestamp('2021-05-17 11:33:00'), 'YOGA', 19.180389850254947],
#  [132, Timestamp('2021-08-03 14:12:00'), 'RUNNING', 25.458923959484252],
#  [133, Timestamp('2021-07-18 10:21:00'), 'BASKETBALL', 62.436416355554826],
#  [134, Timestamp('2021-04-03 10:59:00'), 'JOGGING', 23.403848301184006],
#  [135, Timestamp('2021-05-10 09:29:00'), 'RUNNING', 9.232080666404554],
#  [136, Timestamp('2021-04-10 12:13:00'), 'BASKETBALL', 24.37228830367941],
#  [137, Timestamp('2021-03-27 09:47:00'), 'WALKING', ''],
#  [138, Timestamp('2021-03-23 13:59:00'), 'JOGGING', 17.188118525894087],
#  [139, Timestamp('2021-03-14 11:16:00'), 'JOGGING', 21.225910688039434],
#  [140, Timestamp('2021-08-09 14:08:00'), 'WALKING', 6.733612033808184],
#  [141, Timestamp('2021-08-03 14:33:00'), 'WALKING', 9.11560965770966],
#  [142, Timestamp('2021-08-02 13:36:00'), 'BASKETBALL', ''],
#  [143, Timestamp('2021-05-09 13:08:00'), 'YOGA', 16.203047244163084],
#  [144, Timestamp('2021-03-25 09:58:00'), 'WALKING', 85.61073541477127],
#  [145, Timestamp('2021-05-06 14:45:00'), 'RUNNING', 0.33860774843724345],
#  [146, Timestamp('2021-06-03 12:38:00'), 'YOGA', 14.373018180942084],
#  [147, Timestamp('2021-06-09 11:41:00'), 'RUNNING', 28.748198712452744],
#  [148, Timestamp('2021-04-26 13:37:00'), 'WALKING', 1.446566767333977],
#  [149,
#   Timestamp('2021-05-05 11:57:00'),
#   'STRENGTH_TRAINING',
#   5.057619044309385],
#  [150,
#   Timestamp('2021-04-08 14:21:00'),
#   'TREADMILL_RUNNING',
#   35.35292424485796],
#  [151, Timestamp('2021-08-17 14:06:00'), 'RUNNING', 22.029806215035478],
#  [152, Timestamp('2021-05-10 09:13:00'), 'WALKING', ''],
#  [153, Timestamp('2021-03-26 10:42:00'), 'WALKING', ''],
#  [154, Timestamp('2021-03-25 10:49:00'), 'JOGGING', ''],
#  [155, Timestamp('2021-06-03 12:10:00'), 'RUNNING', 20.293086506825375],
#  [156,
#   Timestamp('2021-05-10 09:52:00'),
#   'STRENGTH_TRAINING',
#   18.230142646274437],
#  [157, Timestamp('2021-08-20 14:04:00'), 'BASKETBALL', 27.747436223450915],
#  [158,
#   Timestamp('2021-04-26 14:13:00'),
#   'STRENGTH_TRAINING',
#   5.71560352808969],
#  [159, Timestamp('2021-04-06 13:32:00'), 'BODY_AND_MIND', 77.90537208837138],
#  [160, Timestamp('2021-03-26 10:38:00'), 'JOGGING', 20.715973984861048],
#  [161, Timestamp('2021-05-08 11:11:00'), 'RUNNING', 6.9223368605011615],
#  [162, Timestamp('2021-03-26 10:58:00'), 'WALKING', 16.02789272078516],
#  [163, Timestamp('2021-03-25 10:52:00'), 'WALKING', ''],
#  [164, Timestamp('2021-07-26 10:33:00'), 'YOGA', 37.386693510575824],
#  [165, Timestamp('2021-06-07 11:46:00'), 'RUNNING', 8.378092581298887],
#  [166, Timestamp('2021-05-05 11:35:00'), 'WALKING', 0.6731767762339149],
#  [167,
#   Timestamp('2021-04-08 14:34:00'),
#   'TREADMILL_RUNNING',
#   15.893785024096507],
#  [168, Timestamp('2021-08-17 14:32:00'), 'YOGA', 70.7811664828298],
#  [169, Timestamp('2021-05-06 15:09:00'), 'YOGA', 5.625661320272984],
#  [170, Timestamp('2021-06-16 11:02:00'), 'YOGA', 16.200198284576402],
#  [171, Timestamp('2021-04-21 09:39:00'), 'JOGGING', 22.403100180790688],
#  [172, Timestamp('2021-04-27 09:58:00'), 'BASKETBALL', 36.09253648629482],
#  [173, Timestamp('2021-05-17 11:20:00'), 'WALKING', 1.0417812415113221],
#  [174, Timestamp('2021-04-08 14:31:00'), 'WALKING', ''],
#  [175, Timestamp('2021-08-07 14:16:00'), 'YOGA', 39.10723067367815],
#  [176, Timestamp('2021-08-13 13:42:00'), 'RUNNING', 24.573795686729113],
#  [177, Timestamp('2021-08-16 16:03:00'), 'RUNNING', 31.365837582477212],
#  [178, Timestamp('2021-03-28 16:33:00'), 'CYCLING', 14.713420926360731],
#  [179,
#   Timestamp('2021-04-22 12:47:00'),
#   'TREADMILL_RUNNING',
#   35.14271584138153],
#  [180, Timestamp('2021-03-20 10:40:00'), 'JOGGING', 21.395903366895773],
#  [181, Timestamp('2021-07-19 09:53:00'), 'WALKING', 9.315837238875538],
#  [182, Timestamp('2021-07-19 10:25:00'), 'YOGA', 29.092774724629503],
#  [183, Timestamp('2021-03-29 12:28:00'), 'JOGGING', 11.133939259673989],
#  [184, Timestamp('2021-04-17 15:05:00'), 'BASKETBALL', 25.289900938291186],
#  [185, Timestamp('2021-07-20 09:46:00'), 'YOGA', 21.373284060694157],
#  [186, Timestamp('2021-07-31 11:38:00'), 'RUNNING', 31.827449440738764],
#  [187, Timestamp('2021-05-15 10:55:00'), 'YOGA', 22.04688369185292],
#  [188, Timestamp('2021-06-25 14:17:00'), 'RUNNING', 23.754970683017305],
#  [189, Timestamp('2021-06-16 10:53:00'), 'WALKING', 0.1149392661139749],
#  [190, Timestamp('2021-03-14 11:49:00'), 'OTHER_INDOOR', 29.07302245087154],
#  [191, Timestamp('2021-07-27 10:17:00'), 'YOGA', 69.0270808491126],
#  [192, Timestamp('2021-03-12 14:51:00'), 'OTHER_INDOOR', 77.83199449426833],
#  [193,
#   Timestamp('2021-05-17 11:45:00'),
#   'STRENGTH_TRAINING',
#   18.355071543429357],
#  [194,
#   Timestamp('2021-06-16 11:15:00'),
#   'STRENGTH_TRAINING',
#   8.273486780253462],
#  [195, Timestamp('2021-05-18 11:05:00'), 'RUNNING', 16.359860694757636],
#  [196, Timestamp('2021-06-07 11:31:00'), 'RUNNING', 27.34144403654802],
#  [197, Timestamp('2021-06-07 11:43:00'), 'WALKING', 6.122531987488007],
#  [198,
#   Timestamp('2021-07-25 11:35:00'),
#   'STRENGTH_TRAINING',
#   25.31255100762761],
#  [199, Timestamp('2021-03-21 13:27:00'), 'OTHER_INDOOR', 10.78300384332878],
#  [200, Timestamp('2021-05-10 09:15:00'), 'RUNNING', 7.399789107746409],
#  [201, Timestamp('2021-06-20 08:54:00'), 'RUNNING', 19.20822248890249],
#  [202, Timestamp('2021-03-30 13:52:00'), 'WALKING', 17.678079046948284],
#  [203, Timestamp('2021-08-09 13:29:00'), 'RUNNING', 23.11039194853053],
#  [204, Timestamp('2021-04-09 12:25:00'), 'CYCLING', 10.62845343822577],
#  [205,
#   Timestamp('2021-05-18 11:46:00'),
#   'STRENGTH_TRAINING',
#   2.6893914629781652],
#  [206, Timestamp('2021-03-12 14:54:00'), 'JOGGING', 15.033158304360684],
#  [207, Timestamp('2021-04-11 12:20:00'), 'WALKING', 20.760388778957964],
#  [208, Timestamp('2021-08-02 14:30:00'), 'YOGA', 57.050962599917376],
#  [209, Timestamp('2021-06-01 12:01:00'), 'YOGA', 19.948209249863186],
#  [210, Timestamp('2021-03-29 12:33:00'), 'JOGGING', 10.220778231242033],
#  [211,
#   Timestamp('2021-03-26 11:14:00'),
#   'STRENGTH_TRAINING',
#   13.098330439621089],
#  [212,
#   Timestamp('2021-07-26 10:45:00'),
#   'STRENGTH_TRAINING',
#   25.663399247407003],
#  [213, Timestamp('2021-08-13 14:38:00'), 'YOGA', 53.30993823813499],
#  [214, Timestamp('2021-05-18 11:19:00'), 'WALKING', 0.5781582167045445],
#  [215,
#   Timestamp('2021-06-07 12:36:00'),
#   'STRENGTH_TRAINING',
#   11.972438120641192],
#  [216, Timestamp('2021-03-28 15:51:00'), 'CYCLING', 60.12584173717995],
#  [217,
#   Timestamp('2021-04-19 11:38:00'),
#   'TREADMILL_RUNNING',
#   29.797959094569926],
#  [218,
#   Timestamp('2021-05-09 13:24:00'),
#   'STRENGTH_TRAINING',
#   7.750339063776355],
#  [219, Timestamp('2021-03-25 10:28:00'), 'JOGGING', 18.93014806187004],
#  [220, Timestamp('2021-07-25 11:11:00'), 'WALKING', 6.0031287205669805],
#  [221, Timestamp('2021-03-29 12:23:00'), 'WALKING', ''],
#  [222, Timestamp('2021-03-10 14:28:00'), 'OTHER_INDOOR', 118.73629050260767],
#  [223, Timestamp('2021-07-20 09:03:00'), 'RUNNING', 33.8213003025936],
#  [224, Timestamp('2021-05-22 09:50:00'), 'BASKETBALL', 50.74053072010181],
#  [225, Timestamp('2021-05-10 09:22:00'), 'RUNNING', 10.024840943481438],
#  [226, Timestamp('2021-03-27 09:49:00'), 'JOGGING', 12.118705171142022],
#  [227,
#   Timestamp('2021-07-24 10:48:00'),
#   'STRENGTH_TRAINING',
#   30.376781089228952],
#  [228,
#   Timestamp('2021-08-02 14:43:00'),
#   'STRENGTH_TRAINING',
#   23.800980773989895],
#  [229, Timestamp('2021-05-17 11:05:00'), 'RUNNING', 20.300077995658288],
#  [230, Timestamp('2021-04-01 10:42:00'), 'WALKING', ''],
#  [231, Timestamp('2021-04-23 03:35:00'), 'BODY_AND_MIND', 129.0919009335065],
#  [232, Timestamp('2021-05-08 11:00:00'), 'RUNNING', 16.60767851389289],
#  [233, Timestamp('2021-05-23 13:57:00'), 'WALKING', 3838.064058276185],
#  [234, Timestamp('2021-04-26 13:39:00'), 'RUNNING', 6.9284351365307515],
#  [235, Timestamp('2021-04-09 11:44:00'), 'CYCLING', 14.169194013169275],
#  [236, Timestamp('2021-05-10 09:31:00'), 'WALKING', 14.261397688614059],
#  [237, Timestamp('2021-03-15 13:28:00'), 'OTHER_INDOOR', 32.12647526224536],
#  [238,
#   Timestamp('2021-05-06 15:18:00'),
#   'STRENGTH_TRAINING',
#   5.463388649363775],
#  [239, Timestamp('2021-04-11 12:11:00'), 'WALKING', ''],
#  [240, Timestamp('2021-03-25 10:55:00'), 'YOGA', 32.93907271132577],
#  [241, Timestamp('2021-04-21 10:06:00'), 'YOGA', 25.38638723134655],
#  [242, Timestamp('2021-04-11 12:06:00'), 'WALKING', ''],
#  [243,
#   Timestamp('2021-06-01 12:28:00'),
#   'STRENGTH_TRAINING',
#   20.03145247542422],
#  [244, Timestamp('2021-05-28 12:27:00'), 'RUNNING', 19.040869323253016],
#  [245, Timestamp('2021-04-11 12:12:00'), 'JOGGING', ''],
#  [246, Timestamp('2021-03-10 14:36:00'), 'JOGGING', 22.997103554562496],
#  [247, Timestamp('2021-05-10 09:39:00'), 'YOGA', 29.147617304495853],
#  [248, Timestamp('2021-07-23 10:20:00'), 'WALKING', 0.7489675964067161],
#  [249, Timestamp('2021-04-25 12:17:00'), 'RUNNING', 14.54902656361878],
#  [250, Timestamp('2021-08-22 21:08:00'), 'activity-walk', ''],
#  [251, Timestamp('2021-08-23 05:30:00'), 'coffee', ''],
#  [252, Timestamp('2021-08-24 08:18:00'), 'woke up', ''],
#  [253, Timestamp('2021-08-24 02:20:00'), 'Working on computer ', '']]

# %%
i=21.73378181755639
'{0:.3g}'.format(i)
# Out:
# '21.7'

# %%
nan_value=table_lists[4][3]
nan_value
# Out:
# 'nan'

# %%
table_lists
# Out:
# [[1, Timestamp('2021-06-09 12:08:00'), 'YOGA', '21.7'],
#  [2, Timestamp('2021-07-19 09:58:00'), 'RUNNING', '8.91'],
#  [3, Timestamp('2021-04-01 10:53:00'), 'TREADMILL_RUNNING', '15.1'],
#  [4, Timestamp('2021-03-21 13:01:00'), 'JOGGING', '11'],
#  [5, Timestamp('2021-03-29 12:26:00'), 'WALKING', 'nan'],
#  [6, Timestamp('2021-05-21 12:00:00'), 'STRENGTH_TRAINING', '22.2'],
#  [7, Timestamp('2021-03-26 10:46:00'), 'WALKING', '28.6'],
#  [8, Timestamp('2021-06-09 12:00:00'), 'WALKING', '0.103'],
#  [9, Timestamp('2021-07-24 10:07:00'), 'RUNNING', '10.4'],
#  [10, Timestamp('2021-04-21 09:59:00'), 'WALKING', '0.159'],
#  [11, Timestamp('2021-06-07 11:58:00'), 'RUNNING', '5.95'],
#  [12, Timestamp('2021-04-11 12:15:00'), 'JOGGING', '11.3'],
#  [13, Timestamp('2021-03-26 11:03:00'), 'YOGA', '35.4'],
#  [14, Timestamp('2021-05-15 11:09:00'), 'STRENGTH_TRAINING', '17'],
#  [15, Timestamp('2021-06-07 12:08:00'), 'WALKING', '0.0361'],
#  [16, Timestamp('2021-05-17 11:23:00'), 'RUNNING', '4.64'],
#  [17, Timestamp('2021-08-09 14:18:00'), 'YOGA', '53.3'],
#  [18, Timestamp('2021-05-18 11:32:00'), 'YOGA', '11.9'],
#  [19, Timestamp('2021-04-25 12:47:00'), 'YOGA', '20.4'],
#  [20, Timestamp('2021-07-19 10:13:00'), 'WALKING', '3.32'],
#  [21, Timestamp('2021-05-25 11:55:00'), 'RUNNING', '37.7'],
#  [22, Timestamp('2021-07-31 12:40:00'), 'STRENGTH_TRAINING', '31'],
#  [23, Timestamp('2021-05-18 11:26:00'), 'WALKING', '0.147'],
#  [24, Timestamp('2021-03-30 13:44:00'), 'JOGGING', '15.7'],
#  [25, Timestamp('2021-03-30 14:26:00'), 'STRENGTH_TRAINING', '32.1'],
#  [26, Timestamp('2021-03-25 10:42:00'), 'JOGGING', 'nan'],
#  [27, Timestamp('2021-04-03 11:03:00'), 'WALKING', 'nan'],
#  [28, Timestamp('2021-03-17 11:41:00'), 'OTHER_INDOOR', '18.5'],
#  [29, Timestamp('2021-07-19 09:32:00'), 'RUNNING', '23.8'],
#  [30, Timestamp('2021-05-05 11:16:00'), 'RUNNING', '23'],
#  [31, Timestamp('2021-05-21 11:17:00'), 'RUNNING', '18.1'],
#  [32, Timestamp('2021-04-26 13:42:00'), 'WALKING', '3.61'],
#  [33, Timestamp('2021-04-08 14:39:00'), 'WALKING', '24.9'],
#  [34, Timestamp('2021-05-08 11:08:00'), 'WALKING', '4.55'],
#  [35, Timestamp('2021-03-27 09:53:00'), 'WALKING', '27.2'],
#  [36, Timestamp('2021-07-20 09:39:00'), 'WALKING', '2.04'],
#  [37, Timestamp('2021-07-31 12:15:00'), 'WALKING', '2.14'],
#  [38, Timestamp('2021-06-18 09:44:00'), 'WALKING', '0.153'],
#  [39, Timestamp('2021-03-29 12:40:00'), 'JOGGING', '9.9'],
#  [40, Timestamp('2021-07-25 11:23:00'), 'YOGA', '47.2'],
#  [41, Timestamp('2021-08-13 14:52:00'), 'STRENGTH_TRAINING', '45.5'],
#  [42, Timestamp('2021-04-26 14:01:00'), 'YOGA', '22.2'],
#  [43, Timestamp('2021-03-31 12:06:00'), 'JOGGING', '12.4'],
#  [44, Timestamp('2021-04-20 11:15:00'), 'JOGGING', '9.35'],
#  [45, Timestamp('2021-05-21 11:36:00'), 'WALKING', '19.4'],
#  [46, Timestamp('2021-05-10 09:25:00'), 'WALKING', '22.7'],
#  [47, Timestamp('2021-03-30 13:56:00'), 'JOGGING', '10.8'],
#  [48, Timestamp('2021-03-25 18:49:00'), 'WALKING', '40.7'],
#  [49, Timestamp('2021-03-27 09:58:00'), 'YOGA', '45.9'],
#  [50, Timestamp('2021-03-31 11:53:00'), 'JOGGING', '19.3'],
#  [51, Timestamp('2021-06-03 12:53:00'), 'STRENGTH_TRAINING', '15.7'],
#  [52, Timestamp('2021-06-01 11:22:00'), 'BASKETBALL', '50'],
#  [53, Timestamp('2021-07-31 12:24:00'), 'YOGA', '35.9'],
#  [54, Timestamp('2021-08-03 14:44:00'), 'YOGA', '33.9'],
#  [55, Timestamp('2021-05-27 11:12:00'), 'RUNNING', '18.6'],
#  [56, Timestamp('2021-03-28 16:07:00'), 'BASKETBALL', '11.6'],
#  [57, Timestamp('2021-08-14 13:21:00'), 'YOGA', '31.2'],
#  [58, Timestamp('2021-04-20 11:04:00'), 'JOGGING', '7.66'],
#  [59, Timestamp('2021-05-09 12:27:00'), 'RUNNING', '17.4'],
#  [60, Timestamp('2021-04-03 11:06:00'), 'JOGGING', '17'],
#  [61, Timestamp('2021-03-16 11:54:00'), 'JOGGING', '15.4'],
#  [62, Timestamp('2021-04-11 12:02:00'), 'JOGGING', '19.6'],
#  [63, Timestamp('2021-06-07 11:54:00'), 'WALKING', '0.405'],
#  [64, Timestamp('2021-05-16 12:04:00'), 'STRENGTH_TRAINING', '18.6'],
#  [65, Timestamp('2021-03-29 12:54:00'), 'YOGA', '34.5'],
#  [66, Timestamp('2021-08-14 13:06:00'), 'WALKING', '2.31'],
#  [67, Timestamp('2021-06-18 09:26:00'), 'RUNNING', '25.4'],
#  [68, Timestamp('2021-03-29 12:24:00'), 'JOGGING', 'nan'],
#  [69, Timestamp('2021-07-24 10:33:00'), 'YOGA', '39.7'],
#  [70, Timestamp('2021-03-17 11:12:00'), 'JOGGING', '17.9'],
#  [71, Timestamp('2021-03-29 12:19:00'), 'JOGGING', '22'],
#  [72, Timestamp('2021-05-15 10:27:00'), 'RUNNING', '23.9'],
#  [73, Timestamp('2021-08-07 13:27:00'), 'RUNNING', '27.7'],
#  [74, Timestamp('2021-07-30 13:03:00'), 'WALKING', '1.28'],
#  [75, Timestamp('2021-04-08 14:45:00'), 'YOGA', '32.7'],
#  [76, Timestamp('2021-03-10 15:11:00'), 'OTHER_INDOOR', '33'],
#  [77, Timestamp('2021-03-26 10:49:00'), 'JOGGING', '10.9'],
#  [78, Timestamp('2021-05-21 11:45:00'), 'YOGA', '32'],
#  [79, Timestamp('2021-05-27 11:39:00'), 'YOGA', '38.9'],
#  [80, Timestamp('2021-05-10 09:17:00'), 'WALKING', '9.69'],
#  [81, Timestamp('2021-03-26 10:43:00'), 'JOGGING', '10.3'],
#  [82, Timestamp('2021-07-21 10:40:00'), 'BASKETBALL', '46.3'],
#  [83, Timestamp('2021-05-23 13:37:00'), 'RUNNING', '27.4'],
#  [84, Timestamp('2021-03-30 14:01:00'), 'WALKING', '20.5'],
#  [85, Timestamp('2021-05-18 11:22:00'), 'RUNNING', '3.56'],
#  [86, Timestamp('2021-04-11 12:08:00'), 'JOGGING', 'nan'],
#  [87, Timestamp('2021-05-08 11:14:00'), 'WALKING', '0.843'],
#  [88, Timestamp('2021-04-09 11:52:00'), 'BASKETBALL', '33.6'],
#  [89, Timestamp('2021-03-23 14:25:00'), 'OTHER_INDOOR', '918'],
#  [90, Timestamp('2021-03-15 13:01:00'), 'JOGGING', '21.5'],
#  [91, Timestamp('2021-07-23 09:44:00'), 'RUNNING', '26.4'],
#  [92, Timestamp('2021-03-25 09:46:00'), 'BODY_AND_MIND', '153'],
#  [93, Timestamp('2021-03-29 13:07:00'), 'STRENGTH_TRAINING', '23.6'],
#  [94, Timestamp('2021-06-03 12:30:00'), 'WALKING', '9.53'],
#  [95, Timestamp('2021-06-20 09:11:00'), 'WALKING', '2.01'],
#  [96, Timestamp('2021-03-31 12:20:00'), 'YOGA', '29.3'],
#  [97, Timestamp('2021-03-30 14:12:00'), 'YOGA', '34.1'],
#  [98, Timestamp('2021-06-25 15:01:00'), 'YOGA', '19.1'],
#  [99, Timestamp('2021-06-07 12:26:00'), 'YOGA', '15.8'],
#  [100, Timestamp('2021-07-25 10:31:00'), 'RUNNING', '27'],
#  [101, Timestamp('2021-04-01 10:50:00'), 'WALKING', 'nan'],
#  [102, Timestamp('2021-05-05 11:27:00'), 'WALKING', 'nan'],
#  [103, Timestamp('2021-05-05 11:29:00'), 'RUNNING', '4.16'],
#  [104, Timestamp('2021-08-14 12:44:00'), 'RUNNING', '23.8'],
#  [105, Timestamp('2021-03-12 15:25:00'), 'OTHER_INDOOR', '18.8'],
#  [106, Timestamp('2021-05-05 11:45:00'), 'YOGA', '11.7'],
#  [107, Timestamp('2021-04-11 12:14:00'), 'WALKING', 'nan'],
#  [108, Timestamp('2021-05-16 11:23:00'), 'RUNNING', '18.5'],
#  [109, Timestamp('2021-07-30 12:29:00'), 'RUNNING', '30.7'],
#  [110, Timestamp('2021-05-16 11:50:00'), 'YOGA', '27.9'],
#  [111, Timestamp('2021-06-25 15:13:00'), 'STRENGTH_TRAINING', '15.8'],
#  [112, Timestamp('2021-07-26 09:53:00'), 'RUNNING', '21.1'],
#  [113, Timestamp('2021-08-07 14:02:00'), 'WALKING', '5.44'],
#  [114, Timestamp('2021-08-12 13:58:00'), 'RUNNING', '22.5'],
#  [115, Timestamp('2021-04-01 10:59:00'), 'WALKING', '21.4'],
#  [116, Timestamp('2021-04-01 10:29:00'), 'JOGGING', '56.6'],
#  [117, Timestamp('2021-06-16 10:33:00'), 'RUNNING', '18.4'],
#  [118, Timestamp('2021-04-01 11:04:00'), 'YOGA', '36'],
#  [119, Timestamp('2021-08-09 14:36:00'), 'STRENGTH_TRAINING', '19.5'],
#  [120, Timestamp('2021-08-13 14:09:00'), 'WALKING', '22'],
#  [121, Timestamp('2021-03-25 18:37:00'), 'JOGGING', '18.5'],
#  [122, Timestamp('2021-03-27 09:41:00'), 'JOGGING', '23.5'],
#  [123, Timestamp('2021-07-26 10:24:00'), 'WALKING', '6.18'],
#  [124, Timestamp('2021-03-31 12:01:00'), 'WALKING', '22.7'],
#  [125, Timestamp('2021-04-01 10:44:00'), 'JOGGING', '17.3'],
#  [126, Timestamp('2021-04-26 13:26:00'), 'RUNNING', '15.8'],
#  [127, Timestamp('2021-07-27 09:56:00'), 'RUNNING', '29.5'],
#  [128, Timestamp('2021-05-17 11:26:00'), 'WALKING', '0.362'],
#  [129, Timestamp('2021-05-10 09:05:00'), 'RUNNING', '18'],
#  [130, Timestamp('2021-03-31 12:14:00'), 'WALKING', '18'],
#  [131, Timestamp('2021-05-17 11:33:00'), 'YOGA', '19.2'],
#  [132, Timestamp('2021-08-03 14:12:00'), 'RUNNING', '25.5'],
#  [133, Timestamp('2021-07-18 10:21:00'), 'BASKETBALL', '62.4'],
#  [134, Timestamp('2021-04-03 10:59:00'), 'JOGGING', '23.4'],
#  [135, Timestamp('2021-05-10 09:29:00'), 'RUNNING', '9.23'],
#  [136, Timestamp('2021-04-10 12:13:00'), 'BASKETBALL', '24.4'],
#  [137, Timestamp('2021-03-27 09:47:00'), 'WALKING', 'nan'],
#  [138, Timestamp('2021-03-23 13:59:00'), 'JOGGING', '17.2'],
#  [139, Timestamp('2021-03-14 11:16:00'), 'JOGGING', '21.2'],
#  [140, Timestamp('2021-08-09 14:08:00'), 'WALKING', '6.73'],
#  [141, Timestamp('2021-08-03 14:33:00'), 'WALKING', '9.12'],
#  [142, Timestamp('2021-08-02 13:36:00'), 'BASKETBALL', 'nan'],
#  [143, Timestamp('2021-05-09 13:08:00'), 'YOGA', '16.2'],
#  [144, Timestamp('2021-03-25 09:58:00'), 'WALKING', '85.6'],
#  [145, Timestamp('2021-05-06 14:45:00'), 'RUNNING', '0.339'],
#  [146, Timestamp('2021-06-03 12:38:00'), 'YOGA', '14.4'],
#  [147, Timestamp('2021-06-09 11:41:00'), 'RUNNING', '28.7'],
#  [148, Timestamp('2021-04-26 13:37:00'), 'WALKING', '1.45'],
#  [149, Timestamp('2021-05-05 11:57:00'), 'STRENGTH_TRAINING', '5.06'],
#  [150, Timestamp('2021-04-08 14:21:00'), 'TREADMILL_RUNNING', '35.4'],
#  [151, Timestamp('2021-08-17 14:06:00'), 'RUNNING', '22'],
#  [152, Timestamp('2021-05-10 09:13:00'), 'WALKING', 'nan'],
#  [153, Timestamp('2021-03-26 10:42:00'), 'WALKING', 'nan'],
#  [154, Timestamp('2021-03-25 10:49:00'), 'JOGGING', 'nan'],
#  [155, Timestamp('2021-06-03 12:10:00'), 'RUNNING', '20.3'],
#  [156, Timestamp('2021-05-10 09:52:00'), 'STRENGTH_TRAINING', '18.2'],
#  [157, Timestamp('2021-08-20 14:04:00'), 'BASKETBALL', '27.7'],
#  [158, Timestamp('2021-04-26 14:13:00'), 'STRENGTH_TRAINING', '5.72'],
#  [159, Timestamp('2021-04-06 13:32:00'), 'BODY_AND_MIND', '77.9'],
#  [160, Timestamp('2021-03-26 10:38:00'), 'JOGGING', '20.7'],
#  [161, Timestamp('2021-05-08 11:11:00'), 'RUNNING', '6.92'],
#  [162, Timestamp('2021-03-26 10:58:00'), 'WALKING', '16'],
#  [163, Timestamp('2021-03-25 10:52:00'), 'WALKING', 'nan'],
#  [164, Timestamp('2021-07-26 10:33:00'), 'YOGA', '37.4'],
#  [165, Timestamp('2021-06-07 11:46:00'), 'RUNNING', '8.38'],
#  [166, Timestamp('2021-05-05 11:35:00'), 'WALKING', '0.673'],
#  [167, Timestamp('2021-04-08 14:34:00'), 'TREADMILL_RUNNING', '15.9'],
#  [168, Timestamp('2021-08-17 14:32:00'), 'YOGA', '70.8'],
#  [169, Timestamp('2021-05-06 15:09:00'), 'YOGA', '5.63'],
#  [170, Timestamp('2021-06-16 11:02:00'), 'YOGA', '16.2'],
#  [171, Timestamp('2021-04-21 09:39:00'), 'JOGGING', '22.4'],
#  [172, Timestamp('2021-04-27 09:58:00'), 'BASKETBALL', '36.1'],
#  [173, Timestamp('2021-05-17 11:20:00'), 'WALKING', '1.04'],
#  [174, Timestamp('2021-04-08 14:31:00'), 'WALKING', 'nan'],
#  [175, Timestamp('2021-08-07 14:16:00'), 'YOGA', '39.1'],
#  [176, Timestamp('2021-08-13 13:42:00'), 'RUNNING', '24.6'],
#  [177, Timestamp('2021-08-16 16:03:00'), 'RUNNING', '31.4'],
#  [178, Timestamp('2021-03-28 16:33:00'), 'CYCLING', '14.7'],
#  [179, Timestamp('2021-04-22 12:47:00'), 'TREADMILL_RUNNING', '35.1'],
#  [180, Timestamp('2021-03-20 10:40:00'), 'JOGGING', '21.4'],
#  [181, Timestamp('2021-07-19 09:53:00'), 'WALKING', '9.32'],
#  [182, Timestamp('2021-07-19 10:25:00'), 'YOGA', '29.1'],
#  [183, Timestamp('2021-03-29 12:28:00'), 'JOGGING', '11.1'],
#  [184, Timestamp('2021-04-17 15:05:00'), 'BASKETBALL', '25.3'],
#  [185, Timestamp('2021-07-20 09:46:00'), 'YOGA', '21.4'],
#  [186, Timestamp('2021-07-31 11:38:00'), 'RUNNING', '31.8'],
#  [187, Timestamp('2021-05-15 10:55:00'), 'YOGA', '22'],
#  [188, Timestamp('2021-06-25 14:17:00'), 'RUNNING', '23.8'],
#  [189, Timestamp('2021-06-16 10:53:00'), 'WALKING', '0.115'],
#  [190, Timestamp('2021-03-14 11:49:00'), 'OTHER_INDOOR', '29.1'],
#  [191, Timestamp('2021-07-27 10:17:00'), 'YOGA', '69'],
#  [192, Timestamp('2021-03-12 14:51:00'), 'OTHER_INDOOR', '77.8'],
#  [193, Timestamp('2021-05-17 11:45:00'), 'STRENGTH_TRAINING', '18.4'],
#  [194, Timestamp('2021-06-16 11:15:00'), 'STRENGTH_TRAINING', '8.27'],
#  [195, Timestamp('2021-05-18 11:05:00'), 'RUNNING', '16.4'],
#  [196, Timestamp('2021-06-07 11:31:00'), 'RUNNING', '27.3'],
#  [197, Timestamp('2021-06-07 11:43:00'), 'WALKING', '6.12'],
#  [198, Timestamp('2021-07-25 11:35:00'), 'STRENGTH_TRAINING', '25.3'],
#  [199, Timestamp('2021-03-21 13:27:00'), 'OTHER_INDOOR', '10.8'],
#  [200, Timestamp('2021-05-10 09:15:00'), 'RUNNING', '7.4'],
#  [201, Timestamp('2021-06-20 08:54:00'), 'RUNNING', '19.2'],
#  [202, Timestamp('2021-03-30 13:52:00'), 'WALKING', '17.7'],
#  [203, Timestamp('2021-08-09 13:29:00'), 'RUNNING', '23.1'],
#  [204, Timestamp('2021-04-09 12:25:00'), 'CYCLING', '10.6'],
#  [205, Timestamp('2021-05-18 11:46:00'), 'STRENGTH_TRAINING', '2.69'],
#  [206, Timestamp('2021-03-12 14:54:00'), 'JOGGING', '15'],
#  [207, Timestamp('2021-04-11 12:20:00'), 'WALKING', '20.8'],
#  [208, Timestamp('2021-08-02 14:30:00'), 'YOGA', '57.1'],
#  [209, Timestamp('2021-06-01 12:01:00'), 'YOGA', '19.9'],
#  [210, Timestamp('2021-03-29 12:33:00'), 'JOGGING', '10.2'],
#  [211, Timestamp('2021-03-26 11:14:00'), 'STRENGTH_TRAINING', '13.1'],
#  [212, Timestamp('2021-07-26 10:45:00'), 'STRENGTH_TRAINING', '25.7'],
#  [213, Timestamp('2021-08-13 14:38:00'), 'YOGA', '53.3'],
#  [214, Timestamp('2021-05-18 11:19:00'), 'WALKING', '0.578'],
#  [215, Timestamp('2021-06-07 12:36:00'), 'STRENGTH_TRAINING', '12'],
#  [216, Timestamp('2021-03-28 15:51:00'), 'CYCLING', '60.1'],
#  [217, Timestamp('2021-04-19 11:38:00'), 'TREADMILL_RUNNING', '29.8'],
#  [218, Timestamp('2021-05-09 13:24:00'), 'STRENGTH_TRAINING', '7.75'],
#  [219, Timestamp('2021-03-25 10:28:00'), 'JOGGING', '18.9'],
#  [220, Timestamp('2021-07-25 11:11:00'), 'WALKING', '6'],
#  [221, Timestamp('2021-03-29 12:23:00'), 'WALKING', 'nan'],
#  [222, Timestamp('2021-03-10 14:28:00'), 'OTHER_INDOOR', '119'],
#  [223, Timestamp('2021-07-20 09:03:00'), 'RUNNING', '33.8'],
#  [224, Timestamp('2021-05-22 09:50:00'), 'BASKETBALL', '50.7'],
#  [225, Timestamp('2021-05-10 09:22:00'), 'RUNNING', '10'],
#  [226, Timestamp('2021-03-27 09:49:00'), 'JOGGING', '12.1'],
#  [227, Timestamp('2021-07-24 10:48:00'), 'STRENGTH_TRAINING', '30.4'],
#  [228, Timestamp('2021-08-02 14:43:00'), 'STRENGTH_TRAINING', '23.8'],
#  [229, Timestamp('2021-05-17 11:05:00'), 'RUNNING', '20.3'],
#  [230, Timestamp('2021-04-01 10:42:00'), 'WALKING', 'nan'],
#  [231, Timestamp('2021-04-23 03:35:00'), 'BODY_AND_MIND', '129'],
#  [232, Timestamp('2021-05-08 11:00:00'), 'RUNNING', '16.6'],
#  [233, Timestamp('2021-05-23 13:57:00'), 'WALKING', '3.84e+03'],
#  [234, Timestamp('2021-04-26 13:39:00'), 'RUNNING', '6.93'],
#  [235, Timestamp('2021-04-09 11:44:00'), 'CYCLING', '14.2'],
#  [236, Timestamp('2021-05-10 09:31:00'), 'WALKING', '14.3'],
#  [237, Timestamp('2021-03-15 13:28:00'), 'OTHER_INDOOR', '32.1'],
#  [238, Timestamp('2021-05-06 15:18:00'), 'STRENGTH_TRAINING', '5.46'],
#  [239, Timestamp('2021-04-11 12:11:00'), 'WALKING', 'nan'],
#  [240, Timestamp('2021-03-25 10:55:00'), 'YOGA', '32.9'],
#  [241, Timestamp('2021-04-21 10:06:00'), 'YOGA', '25.4'],
#  [242, Timestamp('2021-04-11 12:06:00'), 'WALKING', 'nan'],
#  [243, Timestamp('2021-06-01 12:28:00'), 'STRENGTH_TRAINING', '20'],
#  [244, Timestamp('2021-05-28 12:27:00'), 'RUNNING', '19'],
#  [245, Timestamp('2021-04-11 12:12:00'), 'JOGGING', 'nan'],
#  [246, Timestamp('2021-03-10 14:36:00'), 'JOGGING', '23'],
#  [247, Timestamp('2021-05-10 09:39:00'), 'YOGA', '29.1'],
#  [248, Timestamp('2021-07-23 10:20:00'), 'WALKING', '0.749'],
#  [249, Timestamp('2021-04-25 12:17:00'), 'RUNNING', '14.5'],
#  [250, Timestamp('2021-08-22 21:08:00'), 'activity-walk', 'nan'],
#  [251, Timestamp('2021-08-23 05:30:00'), 'coffee', 'nan'],
#  [252, Timestamp('2021-08-24 08:18:00'), 'woke up', 'nan'],
#  [253, Timestamp('2021-08-24 02:20:00'), 'Working on computer ', 'nan']]
